# %%
import json
import os
from io import BytesIO

import matplotlib.patches as patches
import matplotlib.pyplot as plt
import oci
from PIL import Image

# %%
config = oci.config.from_file()

# %%
#Object storage Namespace
object_storage_client = oci.object_storage.ObjectStorageClient(config)
NAMESPACE = object_storage_client.get_namespace().data

#Name of Bucket for this demo
BUCKET_NAME = 'bucket-pruebas'

PREFIX = "notebook"

# %%
type(object_storage_client)
# Out:
# oci.object_storage.object_storage_client.ObjectStorageClient

# %%
DATASET_PATH = "./sample_documents"
FILENAME = "image3.png"

# %%
response = object_storage_client.put_object(NAMESPACE, BUCKET_NAME, FILENAME, open(os.path.join(DATASET_PATH, FILENAME), "rb"))
response.status
# Out:
# 200

# %%
response = object_storage_client.get_object(NAMESPACE, BUCKET_NAME, FILENAME)
response.status
# Out:
# 200

# %%
image = Image.open(BytesIO(response.data.content))
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x1507>

# %%
# Initialize service client with default config file
ai_document_client = oci.ai_document.AIServiceDocumentClient(config)

# %%
# Send the request to service, some parameters are not required, see API
# doc for more info
create_processor_job_response = ai_document_client.create_processor_job(
    create_processor_job_details=oci.ai_document.models.CreateProcessorJobDetails(
        input_location=oci.ai_document.models.ObjectStorageLocations(
            source_type="OBJECT_STORAGE_LOCATIONS",
            object_locations=[
                oci.ai_document.models.ObjectLocation(
                    namespace_name=NAMESPACE,
                    bucket_name=BUCKET_NAME,
                    object_name=FILENAME)]),
        output_location=oci.ai_document.models.OutputLocation(
            namespace_name=NAMESPACE,
            bucket_name=BUCKET_NAME,
            prefix=PREFIX),
        compartment_id=config["compartment_id"],
        processor_config=oci.ai_document.models.GeneralProcessorConfig(
            processor_type="GENERAL",
            features=[
                oci.ai_document.models.DocumentTextExtractionFeature(
                    feature_type="TEXT_EXTRACTION",
                    generate_searchable_pdf=True)],
            document_type="OTHERS",
            is_zip_output_enabled=True,
            language="es"),
        display_name="EXAMPLE-displayName-Value"),
    opc_retry_token="EXAMPLE-opcRetryToken-Value",
    opc_request_id="MOZIJVR14UCLBIBEOUH8<unique_ID>")

# %%
time_accepted = create_processor_job_response.data.time_accepted
time_started = create_processor_job_response.data.time_started
time_finished = create_processor_job_response.data.time_finished

# Calculate the time taken to process the document
time_taken = time_finished - time_started
print("It took {} seconds to process the document".format(time_taken.total_seconds()))
# Out:
# It took 0.0 seconds to process the document

# %%
output_location = "{}_{}".format(create_processor_job_response.data.output_location.namespace_name, create_processor_job_response.data.output_location.bucket_name)

# %%
results_path = os.path.join(PREFIX, create_processor_job_response.data.id, output_location, "results", FILENAME+".json")

# %%
response = object_storage_client.get_object(NAMESPACE, BUCKET_NAME, results_path)
response.status
# Out:
# 200

# %%
bytes_json = response.data.content
json_data = json.loads(bytes_json)
json_data
# Out:
# {'documentMetadata': {'pageCount': 1, 'mimeType': 'image/png'},
#  'pages': [{'pageNumber': 1,
#    'dimensions': {'width': 2000.0, 'height': 1507.0, 'unit': 'PIXEL'},
#    'detectedDocumentTypes': None,
#    'detectedLanguages': None,
#    'words': [{'text': 'COL',
#      'confidence': 0.98602766,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.075,
#         'y': 0.12209688122096882},
#        {'x': 0.236, 'y': 0.12740544127405443},
#        {'x': 0.2345, 'y': 0.20437956204379562},
#        {'x': 0.0735, 'y': 0.19907100199071}]}},
#     {'text': 'REPUBLICA',
#      'confidence': 0.98261696,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.2845,
#         'y': 0.12411829107394658},
#        {'x': 0.484, 'y': 0.12718076142714207},
#        {'x': 0.4835073547363281, 'y': 0.171639951871734},
#        {'x': 0.2840073547363281, 'y': 0.1685774815185385}]}},
#     {'text': 'DE',
#      'confidence': 0.98261696,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.495,
#         'y': 0.12734962063430552},
#        {'x': 0.553, 'y': 0.12823996641972876},
#        {'x': 0.55250732421875, 'y': 0.17269915686432066},
#        {'x': 0.4945073547363281, 'y': 0.17180880095362266}]}},
#     {'text': 'COLOMBIA',
#      'confidence': 0.98261696,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5585,
#         'y': 0.1283243909606731},
#        {'x': 0.755, 'y': 0.1313408115642626},
#        {'x': 0.75450732421875, 'y': 0.1758000020088545},
#        {'x': 0.55800732421875, 'y': 0.172783581405265}]}},
#     {'text': 'Cédula',
#      'confidence': 0.97517586,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.364,
#         'y': 0.1678832116788321},
#        {'x': 0.471, 'y': 0.17011950011275506},
#        {'x': 0.4705082092285156, 'y': 0.20993370051089708},
#        {'x': 0.3635082092285156, 'y': 0.20769741207697412}]}},
#     {'text': 'de',
#      'confidence': 0.97517586,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.471,
#         'y': 0.17011950011275506},
#        {'x': 0.517, 'y': 0.1710808949511654},
#        {'x': 0.5165081787109375, 'y': 0.2108950953493074},
#        {'x': 0.4705082092285156, 'y': 0.20993370051089708}]}},
#     {'text': 'Extranjeria',
#      'confidence': 0.97517586,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.52,
#         'y': 0.17114359065247595},
#        {'x': 0.6795, 'y': 0.1744771146109821},
#        {'x': 0.6790081787109375, 'y': 0.2142913150091241},
#        {'x': 0.5195081787109375, 'y': 0.21095779105061796}]}},
#     {'text': 'RESIDENTE',
#      'confidence': 0.9885698,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.3359681396484375,
#         'y': 0.23421408913352273},
#        {'x': 0.5256049194335938, 'y': 0.23220758368499086},
#        {'x': 0.5260985107421875, 'y': 0.2829340761990917},
#        {'x': 0.33646173095703125, 'y': 0.2846576207191958}]}},
#     {'text': 'No.',
#      'confidence': 0.9885698,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5505840454101563,
#         'y': 0.23194327351267005},
#        {'x': 0.609178955078125, 'y': 0.23132330293914855},
#        {'x': 0.6096725463867188, 'y': 0.2821744983371869},
#        {'x': 0.5510776977539062, 'y': 0.2827070472884352}]}},
#     {'text': '0000000',
#      'confidence': 0.9885698,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.609178955078125,
#         'y': 0.23132330293914855},
#        {'x': 0.7719935302734375, 'y': 0.22960058869157474},
#        {'x': 0.7724871215820313, 'y': 0.28069472993219147},
#        {'x': 0.6096725463867188, 'y': 0.2821744983371869}]}},
#     {'text': '000',
#      'confidence': 0.6282883,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.793,
#         'y': 0.22229595222295953},
#        {'x': 0.892, 'y': 0.2183145321831453},
#        {'x': 0.893, 'y': 0.26277372262773724},
#        {'x': 0.794, 'y': 0.2667551426675514}]}},
#     {'text': '*DO',
#      'confidence': 0.89503556,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.352,
#         'y': 0.3278035832780358},
#        {'x': 0.46233071899414063, 'y': 0.32714989553956536},
#        {'x': 0.46249237060546877, 'y': 0.36961740393787323},
#        {'x': 0.352, 'y': 0.37027109167634376}]}},
#     {'text': 'BARROW',
#      'confidence': 0.89503556,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.4728149108886719,
#         'y': 0.32708778710419084},
#        {'x': 0.6051190185546875, 'y': 0.3263039288334128},
#        {'x': 0.6054899291992187, 'y': 0.3687714169811712},
#        {'x': 0.47299191284179687, 'y': 0.3695553157530483}]}},
#     {'text': 'LASS',
#      'confidence': 0.89503556,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.6071161499023437,
#         'y': 0.3262920822619443},
#        {'x': 0.687500732421875, 'y': 0.3258158298383585},
#        {'x': 0.6879922485351563, 'y': 0.36828333823666637},
#        {'x': 0.6074899291992187, 'y': 0.36875959066025216}]}},
#     {'text': 'NOMEREL',
#      'confidence': 0.5731344,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.3525,
#         'y': 0.41539482415394824},
#        {'x': 0.4855, 'y': 0.40875912408759124},
#        {'x': 0.4865, 'y': 0.44127405441274054},
#        {'x': 0.3535, 'y': 0.44790975447909753}]}},
#     {'text': 'MELDA',
#      'confidence': 0.99526006,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.4755,
#         'y': 0.40212342402123424},
#        {'x': 0.576, 'y': 0.4011280690112807},
#        {'x': 0.5764918212890625, 'y': 0.4409422694094227},
#        {'x': 0.4759917907714844, 'y': 0.44193762441937623}]}},
#     {'text': 'MARIE',
#      'confidence': 0.99526006,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5795,
#         'y': 0.4010934000705043},
#        {'x': 0.676, 'y': 0.4001376551354098},
#        {'x': 0.6764918212890625, 'y': 0.43995185553355176},
#        {'x': 0.5799918212890625, 'y': 0.4409076004686463}]}},
#     {'text': 'NACIONALDAD',
#      'confidence': 0.8020619,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.352,
#         'y': 0.47644326476443266},
#        {'x': 0.511, 'y': 0.47104414425389846},
#        {'x': 0.5114928588867188, 'y': 0.5168304747117618},
#        {'x': 0.3524928588867188, 'y': 0.522229595222296}]}},
#     {'text': 'USA',
#      'confidence': 0.8020619,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5115,
#         'y': 0.47102717429340163},
#        {'x': 0.586, 'y': 0.4684973946453011},
#        {'x': 0.5864928588867188, 'y': 0.5142837251031644},
#        {'x': 0.5119928588867187, 'y': 0.516813504751265}]}},
#     {'text': '.',
#      'confidence': 0.8684699,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.41,
#         'y': 0.4936960849369608},
#        {'x': 0.419, 'y': 0.4936960849369608},
#        {'x': 0.419, 'y': 0.5009953550099535},
#        {'x': 0.41, 'y': 0.5009953550099535}]}},
#     {'text': 'FECHA',
#      'confidence': 0.88047075,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.3495,
#         'y': 0.5507631055076311},
#        {'x': 0.41675, 'y': 0.548303473763064},
#        {'x': 0.4177357177734375, 'y': 0.5940898042209274},
#        {'x': 0.3504857177734375, 'y': 0.5965494359654944}]}},
#     {'text': 'DE',
#      'confidence': 0.88047075,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.41675,
#         'y': 0.548303473763064},
#        {'x': 0.451, 'y': 0.5470507747698241},
#        {'x': 0.4519857177734375, 'y': 0.5928371052276875},
#        {'x': 0.4177357177734375, 'y': 0.5940898042209274}]}},
#     {'text': 'NACIHINTO',
#      'confidence': 0.88047075,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.451,
#         'y': 0.5470507747698241},
#        {'x': 0.579, 'y': 0.5423692122309431},
#        {'x': 0.5799857177734375, 'y': 0.5881555426888064},
#        {'x': 0.4519857177734375, 'y': 0.5928371052276875}]}},
#     {'text': '1981/06/15',
#      'confidence': 0.88047075,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5835,
#         'y': 0.5422046157644533},
#        {'x': 0.73, 'y': 0.5368464418650465},
#        {'x': 0.7309857177734375, 'y': 0.5826327723229098},
#        {'x': 0.5844857177734375, 'y': 0.5879909462223167}]}},
#     {'text': 'TxO',
#      'confidence': 0.62854147,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.348,
#         'y': 0.6204379562043796},
#        {'x': 0.4095, 'y': 0.6172214399209937},
#        {'x': 0.41098001098632814, 'y': 0.6663256204120355},
#        {'x': 0.34948001098632814, 'y': 0.6695421366954214}]}},
#     {'text': 'F',
#      'confidence': 0.62854147,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.418,
#         'y': 0.6167768998579546},
#        {'x': 0.449, 'y': 0.6151555598612723},
#        {'x': 0.4504800109863281, 'y': 0.6642597403523142},
#        {'x': 0.41948001098632814, 'y': 0.6658810803489964}]}},
#     {'text': '*',
#      'confidence': 0.75050914,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5395,
#         'y': 0.6138022561380225},
#        {'x': 0.575841796875, 'y': 0.614868123561401},
#        {'x': 0.5748573608398437, 'y': 0.6564108298642792},
#        {'x': 0.538515625, 'y': 0.6556072880593687}]}},
#     {'text': 'A+',
#      'confidence': 0.75050914,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5843560791015625,
#         'y': 0.6151178533380682},
#        {'x': 0.6295077514648437, 'y': 0.6164421177733079},
#        {'x': 0.6285233764648438, 'y': 0.6575974715649884},
#        {'x': 0.5833716430664062, 'y': 0.6565991194737061}]}},
#     {'text': 'EEPIICON',
#      'confidence': 0.804409,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.4595,
#         'y': 0.6901128069011281},
#        {'x': 0.5822600708007812, 'y': 0.6871559836647727},
#        {'x': 0.5829727783203125, 'y': 0.7342683201051343},
#        {'x': 0.4599930419921875, 'y': 0.7372250623392916}]}},
#     {'text': '2016/10/13',
#      'confidence': 0.804409,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5852545776367187,
#         'y': 0.6870838917084854},
#        {'x': 0.7345007934570312, 'y': 0.6834890951600863},
#        {'x': 0.7354859619140625, 'y': 0.7306014316004479},
#        {'x': 0.5859725952148438, 'y': 0.7341961471466489}]}},
#     {'text': '.',
#      'confidence': 0.60911226,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.125,
#         'y': 0.7723954877239548},
#        {'x': 0.2295, 'y': 0.7723954877239548},
#        {'x': 0.2295, 'y': 0.8500331785003318},
#        {'x': 0.125, 'y': 0.8500331785003318}]}},
#     {'text': 'VINCE',
#      'confidence': 0.7556486,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.458,
#         'y': 0.7777040477770405},
#        {'x': 0.5245, 'y': 0.7750497677504977},
#        {'x': 0.5255, 'y': 0.8128732581287326},
#        {'x': 0.4585, 'y': 0.8161911081619111}]}},
#     {'text': '2021/10/15',
#      'confidence': 0.99955404,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5875,
#         'y': 0.7617783676177837},
#        {'x': 0.7355, 'y': 0.7558062375580624},
#        {'x': 0.7365, 'y': 0.8022561380225613},
#        {'x': 0.5885, 'y': 0.807564698075647}]}},
#     {'text': '.',
#      'confidence': 0.8023063,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.8195,
#         'y': 0.7976111479761114},
#        {'x': 0.8455, 'y': 0.7976111479761114},
#        {'x': 0.8455, 'y': 0.8135368281353683},
#        {'x': 0.8195, 'y': 0.8135368281353683}]}},
#     {'text': '.',
#      'confidence': 0.7507085,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.8645,
#         'y': 0.8002654280026543},
#        {'x': 0.8735, 'y': 0.8002654280026543},
#        {'x': 0.8735, 'y': 0.807564698075647},
#        {'x': 0.8645, 'y': 0.807564698075647}]}},
#     {'text': '.',
#      'confidence': 0.6995067,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.875,
#         'y': 0.79628400796284},
#        {'x': 0.898, 'y': 0.79628400796284},
#        {'x': 0.898, 'y': 0.809555408095554},
#        {'x': 0.875, 'y': 0.809555408095554}]}},
#     {'text': '.',
#      'confidence': 0.74205714,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.1645,
#         'y': 0.8546781685467817},
#        {'x': 0.2195, 'y': 0.8546781685467817},
#        {'x': 0.2195, 'y': 0.8838752488387525},
#        {'x': 0.1645, 'y': 0.8838752488387525}]}}],
#    'lines': [{'text': 'COL',
#      'confidence': 0.98602766,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.075,
#         'y': 0.12209688122096882},
#        {'x': 0.236, 'y': 0.12740544127405443},
#        {'x': 0.2345, 'y': 0.20437956204379562},
#        {'x': 0.0735, 'y': 0.19907100199071}]},
#      'wordIndexes': [0]},
#     {'text': 'REPUBLICA DE COLOMBIA',
#      'confidence': 0.98261696,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.2825,
#         'y': 0.12408759124087591},
#        {'x': 0.758, 'y': 0.13138686131386862},
#        {'x': 0.7575, 'y': 0.17650962176509621},
#        {'x': 0.282, 'y': 0.16921035169210352}]},
#      'wordIndexes': [1, 2, 3]},
#     {'text': 'Cédula de Extranjeria',
#      'confidence': 0.97517586,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.364,
#         'y': 0.1678832116788321},
#        {'x': 0.6815, 'y': 0.1745189117451891},
#        {'x': 0.681, 'y': 0.2149966821499668},
#        {'x': 0.3635, 'y': 0.2083609820836098}]},
#      'wordIndexes': [4, 5, 6]},
#     {'text': 'RESIDENTE No. 0000000',
#      'confidence': 0.9885698,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.3335,
#         'y': 0.2342402123424021},
#        {'x': 0.7725, 'y': 0.22959522229595222},
#        {'x': 0.773, 'y': 0.28135368281353684},
#        {'x': 0.334, 'y': 0.285335102853351}]},
#      'wordIndexes': [7, 8, 9]},
#     {'text': '000',
#      'confidence': 0.6282883,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.793,
#         'y': 0.22229595222295953},
#        {'x': 0.892, 'y': 0.2183145321831453},
#        {'x': 0.893, 'y': 0.26277372262773724},
#        {'x': 0.794, 'y': 0.2667551426675514}]},
#      'wordIndexes': [10]},
#     {'text': '*DO BARROW LASS',
#      'confidence': 0.89503556,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.352,
#         'y': 0.3278035832780358},
#        {'x': 0.688, 'y': 0.32581287325812874},
#        {'x': 0.6885, 'y': 0.36894492368944926},
#        {'x': 0.352, 'y': 0.37093563370935634}]},
#      'wordIndexes': [11, 12, 13]},
#     {'text': 'NOMEREL',
#      'confidence': 0.5731344,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.3525,
#         'y': 0.41539482415394824},
#        {'x': 0.4855, 'y': 0.40875912408759124},
#        {'x': 0.4865, 'y': 0.44127405441274054},
#        {'x': 0.3535, 'y': 0.44790975447909753}]},
#      'wordIndexes': [14]},
#     {'text': 'MELDA MARIE',
#      'confidence': 0.99526006,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.4755,
#         'y': 0.40212342402123424},
#        {'x': 0.6765, 'y': 0.40013271400132716},
#        {'x': 0.677, 'y': 0.44061048440610484},
#        {'x': 0.476, 'y': 0.4426011944260119}]},
#      'wordIndexes': [15, 16]},
#     {'text': 'NACIONALDAD USA',
#      'confidence': 0.8020619,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.352,
#         'y': 0.47644326476443266},
#        {'x': 0.5865, 'y': 0.4684804246848042},
#        {'x': 0.587, 'y': 0.5149303251493033},
#        {'x': 0.3525, 'y': 0.5228931652289317}]},
#      'wordIndexes': [17, 18]},
#     {'text': '.',
#      'confidence': 0.8684699,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.41,
#         'y': 0.4936960849369608},
#        {'x': 0.419, 'y': 0.4936960849369608},
#        {'x': 0.419, 'y': 0.5009953550099535},
#        {'x': 0.41, 'y': 0.5009953550099535}]},
#      'wordIndexes': [19]},
#     {'text': 'FECHA DE NACIHINTO 1981/06/15',
#      'confidence': 0.88047075,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.3495,
#         'y': 0.5507631055076311},
#        {'x': 0.7305, 'y': 0.5368281353682813},
#        {'x': 0.7315, 'y': 0.5832780358327804},
#        {'x': 0.3505, 'y': 0.59721300597213}]},
#      'wordIndexes': [20, 21, 22, 23]},
#     {'text': 'TxO F',
#      'confidence': 0.62854147,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.348,
#         'y': 0.6204379562043796},
#        {'x': 0.4495, 'y': 0.6151293961512939},
#        {'x': 0.451, 'y': 0.6648971466489715},
#        {'x': 0.3495, 'y': 0.670205706702057}]},
#      'wordIndexes': [24, 25]},
#     {'text': '* A+',
#      'confidence': 0.75050914,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5395,
#         'y': 0.6138022561380225},
#        {'x': 0.63, 'y': 0.6164565361645654},
#        {'x': 0.629, 'y': 0.6582614465826144},
#        {'x': 0.5385, 'y': 0.6562707365627074}]},
#      'wordIndexes': [26, 27]},
#     {'text': 'EEPIICON 2016/10/13',
#      'confidence': 0.804409,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.4595,
#         'y': 0.6901128069011281},
#        {'x': 0.735, 'y': 0.683477106834771},
#        {'x': 0.736, 'y': 0.7312541473125415},
#        {'x': 0.46, 'y': 0.7378898473788985}]},
#      'wordIndexes': [28, 29]},
#     {'text': '.',
#      'confidence': 0.60911226,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.125,
#         'y': 0.7723954877239548},
#        {'x': 0.2295, 'y': 0.7723954877239548},
#        {'x': 0.2295, 'y': 0.8500331785003318},
#        {'x': 0.125, 'y': 0.8500331785003318}]},
#      'wordIndexes': [30]},
#     {'text': 'VINCE',
#      'confidence': 0.7556486,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.458,
#         'y': 0.7777040477770405},
#        {'x': 0.5245, 'y': 0.7750497677504977},
#        {'x': 0.5255, 'y': 0.8128732581287326},
#        {'x': 0.4585, 'y': 0.8161911081619111}]},
#      'wordIndexes': [31]},
#     {'text': '2021/10/15',
#      'confidence': 0.99955404,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.5875,
#         'y': 0.7617783676177837},
#        {'x': 0.7355, 'y': 0.7558062375580624},
#        {'x': 0.7365, 'y': 0.8022561380225613},
#        {'x': 0.5885, 'y': 0.807564698075647}]},
#      'wordIndexes': [32]},
#     {'text': '.',
#      'confidence': 0.8023063,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.8195,
#         'y': 0.7976111479761114},
#        {'x': 0.8455, 'y': 0.7976111479761114},
#        {'x': 0.8455, 'y': 0.8135368281353683},
#        {'x': 0.8195, 'y': 0.8135368281353683}]},
#      'wordIndexes': [33]},
#     {'text': '.',
#      'confidence': 0.7507085,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.8645,
#         'y': 0.8002654280026543},
#        {'x': 0.8735, 'y': 0.8002654280026543},
#        {'x': 0.8735, 'y': 0.807564698075647},
#        {'x': 0.8645, 'y': 0.807564698075647}]},
#      'wordIndexes': [34]},
#     {'text': '.',
#      'confidence': 0.6995067,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.875,
#         'y': 0.79628400796284},
#        {'x': 0.898, 'y': 0.79628400796284},
#        {'x': 0.898, 'y': 0.809555408095554},
#        {'x': 0.875, 'y': 0.809555408095554}]},
#      'wordIndexes': [35]},
#     {'text': '.',
#      'confidence': 0.74205714,
#      'boundingPolygon': {'normalizedVertices': [{'x': 0.1645,
#         'y': 0.8546781685467817},
#        {'x': 0.2195, 'y': 0.8546781685467817},
#        {'x': 0.2195, 'y': 0.8838752488387525},
#        {'x': 0.1645, 'y': 0.8838752488387525}]},
#      'wordIndexes': [36]}],
#    'tables': None,
#    'documentFields': None}],
#  'detectedDocumentTypes': None,
#  'detectedLanguages': None,
#  'documentClassificationModelVersion': None,
#  'languageClassificationModelVersion': None,
#  'textExtractionModelVersion': '1.13.39',
#  'keyValueExtractionModelVersion': None,
#  'tableExtractionModelVersion': None,
#  'errors': None,
#  'searchablePdf': None}

# %%
dimensions = json_data["pages"][0]["dimensions"]

width = dimensions["width"]
height = dimensions["height"]

dimensions
# Out:
# {'width': 2000.0, 'height': 1507.0, 'unit': 'PIXEL'}

# %%
words = json_data["pages"][0]["words"]
words
# Out:
# [{'text': 'COL',
#   'confidence': 0.98602766,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.075,
#      'y': 0.12209688122096882},
#     {'x': 0.236, 'y': 0.12740544127405443},
#     {'x': 0.2345, 'y': 0.20437956204379562},
#     {'x': 0.0735, 'y': 0.19907100199071}]}},
#  {'text': 'REPUBLICA',
#   'confidence': 0.98261696,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.2845,
#      'y': 0.12411829107394658},
#     {'x': 0.484, 'y': 0.12718076142714207},
#     {'x': 0.4835073547363281, 'y': 0.171639951871734},
#     {'x': 0.2840073547363281, 'y': 0.1685774815185385}]}},
#  {'text': 'DE',
#   'confidence': 0.98261696,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.495,
#      'y': 0.12734962063430552},
#     {'x': 0.553, 'y': 0.12823996641972876},
#     {'x': 0.55250732421875, 'y': 0.17269915686432066},
#     {'x': 0.4945073547363281, 'y': 0.17180880095362266}]}},
#  {'text': 'COLOMBIA',
#   'confidence': 0.98261696,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5585,
#      'y': 0.1283243909606731},
#     {'x': 0.755, 'y': 0.1313408115642626},
#     {'x': 0.75450732421875, 'y': 0.1758000020088545},
#     {'x': 0.55800732421875, 'y': 0.172783581405265}]}},
#  {'text': 'Cédula',
#   'confidence': 0.97517586,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.364,
#      'y': 0.1678832116788321},
#     {'x': 0.471, 'y': 0.17011950011275506},
#     {'x': 0.4705082092285156, 'y': 0.20993370051089708},
#     {'x': 0.3635082092285156, 'y': 0.20769741207697412}]}},
#  {'text': 'de',
#   'confidence': 0.97517586,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.471,
#      'y': 0.17011950011275506},
#     {'x': 0.517, 'y': 0.1710808949511654},
#     {'x': 0.5165081787109375, 'y': 0.2108950953493074},
#     {'x': 0.4705082092285156, 'y': 0.20993370051089708}]}},
#  {'text': 'Extranjeria',
#   'confidence': 0.97517586,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.52,
#      'y': 0.17114359065247595},
#     {'x': 0.6795, 'y': 0.1744771146109821},
#     {'x': 0.6790081787109375, 'y': 0.2142913150091241},
#     {'x': 0.5195081787109375, 'y': 0.21095779105061796}]}},
#  {'text': 'RESIDENTE',
#   'confidence': 0.9885698,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.3359681396484375,
#      'y': 0.23421408913352273},
#     {'x': 0.5256049194335938, 'y': 0.23220758368499086},
#     {'x': 0.5260985107421875, 'y': 0.2829340761990917},
#     {'x': 0.33646173095703125, 'y': 0.2846576207191958}]}},
#  {'text': 'No.',
#   'confidence': 0.9885698,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5505840454101563,
#      'y': 0.23194327351267005},
#     {'x': 0.609178955078125, 'y': 0.23132330293914855},
#     {'x': 0.6096725463867188, 'y': 0.2821744983371869},
#     {'x': 0.5510776977539062, 'y': 0.2827070472884352}]}},
#  {'text': '0000000',
#   'confidence': 0.9885698,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.609178955078125,
#      'y': 0.23132330293914855},
#     {'x': 0.7719935302734375, 'y': 0.22960058869157474},
#     {'x': 0.7724871215820313, 'y': 0.28069472993219147},
#     {'x': 0.6096725463867188, 'y': 0.2821744983371869}]}},
#  {'text': '000',
#   'confidence': 0.6282883,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.793,
#      'y': 0.22229595222295953},
#     {'x': 0.892, 'y': 0.2183145321831453},
#     {'x': 0.893, 'y': 0.26277372262773724},
#     {'x': 0.794, 'y': 0.2667551426675514}]}},
#  {'text': '*DO',
#   'confidence': 0.89503556,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.352,
#      'y': 0.3278035832780358},
#     {'x': 0.46233071899414063, 'y': 0.32714989553956536},
#     {'x': 0.46249237060546877, 'y': 0.36961740393787323},
#     {'x': 0.352, 'y': 0.37027109167634376}]}},
#  {'text': 'BARROW',
#   'confidence': 0.89503556,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.4728149108886719,
#      'y': 0.32708778710419084},
#     {'x': 0.6051190185546875, 'y': 0.3263039288334128},
#     {'x': 0.6054899291992187, 'y': 0.3687714169811712},
#     {'x': 0.47299191284179687, 'y': 0.3695553157530483}]}},
#  {'text': 'LASS',
#   'confidence': 0.89503556,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.6071161499023437,
#      'y': 0.3262920822619443},
#     {'x': 0.687500732421875, 'y': 0.3258158298383585},
#     {'x': 0.6879922485351563, 'y': 0.36828333823666637},
#     {'x': 0.6074899291992187, 'y': 0.36875959066025216}]}},
#  {'text': 'NOMEREL',
#   'confidence': 0.5731344,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.3525,
#      'y': 0.41539482415394824},
#     {'x': 0.4855, 'y': 0.40875912408759124},
#     {'x': 0.4865, 'y': 0.44127405441274054},
#     {'x': 0.3535, 'y': 0.44790975447909753}]}},
#  {'text': 'MELDA',
#   'confidence': 0.99526006,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.4755,
#      'y': 0.40212342402123424},
#     {'x': 0.576, 'y': 0.4011280690112807},
#     {'x': 0.5764918212890625, 'y': 0.4409422694094227},
#     {'x': 0.4759917907714844, 'y': 0.44193762441937623}]}},
#  {'text': 'MARIE',
#   'confidence': 0.99526006,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5795,
#      'y': 0.4010934000705043},
#     {'x': 0.676, 'y': 0.4001376551354098},
#     {'x': 0.6764918212890625, 'y': 0.43995185553355176},
#     {'x': 0.5799918212890625, 'y': 0.4409076004686463}]}},
#  {'text': 'NACIONALDAD',
#   'confidence': 0.8020619,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.352,
#      'y': 0.47644326476443266},
#     {'x': 0.511, 'y': 0.47104414425389846},
#     {'x': 0.5114928588867188, 'y': 0.5168304747117618},
#     {'x': 0.3524928588867188, 'y': 0.522229595222296}]}},
#  {'text': 'USA',
#   'confidence': 0.8020619,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5115,
#      'y': 0.47102717429340163},
#     {'x': 0.586, 'y': 0.4684973946453011},
#     {'x': 0.5864928588867188, 'y': 0.5142837251031644},
#     {'x': 0.5119928588867187, 'y': 0.516813504751265}]}},
#  {'text': '.',
#   'confidence': 0.8684699,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.41,
#      'y': 0.4936960849369608},
#     {'x': 0.419, 'y': 0.4936960849369608},
#     {'x': 0.419, 'y': 0.5009953550099535},
#     {'x': 0.41, 'y': 0.5009953550099535}]}},
#  {'text': 'FECHA',
#   'confidence': 0.88047075,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.3495,
#      'y': 0.5507631055076311},
#     {'x': 0.41675, 'y': 0.548303473763064},
#     {'x': 0.4177357177734375, 'y': 0.5940898042209274},
#     {'x': 0.3504857177734375, 'y': 0.5965494359654944}]}},
#  {'text': 'DE',
#   'confidence': 0.88047075,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.41675,
#      'y': 0.548303473763064},
#     {'x': 0.451, 'y': 0.5470507747698241},
#     {'x': 0.4519857177734375, 'y': 0.5928371052276875},
#     {'x': 0.4177357177734375, 'y': 0.5940898042209274}]}},
#  {'text': 'NACIHINTO',
#   'confidence': 0.88047075,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.451,
#      'y': 0.5470507747698241},
#     {'x': 0.579, 'y': 0.5423692122309431},
#     {'x': 0.5799857177734375, 'y': 0.5881555426888064},
#     {'x': 0.4519857177734375, 'y': 0.5928371052276875}]}},
#  {'text': '1981/06/15',
#   'confidence': 0.88047075,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5835,
#      'y': 0.5422046157644533},
#     {'x': 0.73, 'y': 0.5368464418650465},
#     {'x': 0.7309857177734375, 'y': 0.5826327723229098},
#     {'x': 0.5844857177734375, 'y': 0.5879909462223167}]}},
#  {'text': 'TxO',
#   'confidence': 0.62854147,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.348,
#      'y': 0.6204379562043796},
#     {'x': 0.4095, 'y': 0.6172214399209937},
#     {'x': 0.41098001098632814, 'y': 0.6663256204120355},
#     {'x': 0.34948001098632814, 'y': 0.6695421366954214}]}},
#  {'text': 'F',
#   'confidence': 0.62854147,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.418,
#      'y': 0.6167768998579546},
#     {'x': 0.449, 'y': 0.6151555598612723},
#     {'x': 0.4504800109863281, 'y': 0.6642597403523142},
#     {'x': 0.41948001098632814, 'y': 0.6658810803489964}]}},
#  {'text': '*',
#   'confidence': 0.75050914,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5395,
#      'y': 0.6138022561380225},
#     {'x': 0.575841796875, 'y': 0.614868123561401},
#     {'x': 0.5748573608398437, 'y': 0.6564108298642792},
#     {'x': 0.538515625, 'y': 0.6556072880593687}]}},
#  {'text': 'A+',
#   'confidence': 0.75050914,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5843560791015625,
#      'y': 0.6151178533380682},
#     {'x': 0.6295077514648437, 'y': 0.6164421177733079},
#     {'x': 0.6285233764648438, 'y': 0.6575974715649884},
#     {'x': 0.5833716430664062, 'y': 0.6565991194737061}]}},
#  {'text': 'EEPIICON',
#   'confidence': 0.804409,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.4595,
#      'y': 0.6901128069011281},
#     {'x': 0.5822600708007812, 'y': 0.6871559836647727},
#     {'x': 0.5829727783203125, 'y': 0.7342683201051343},
#     {'x': 0.4599930419921875, 'y': 0.7372250623392916}]}},
#  {'text': '2016/10/13',
#   'confidence': 0.804409,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5852545776367187,
#      'y': 0.6870838917084854},
#     {'x': 0.7345007934570312, 'y': 0.6834890951600863},
#     {'x': 0.7354859619140625, 'y': 0.7306014316004479},
#     {'x': 0.5859725952148438, 'y': 0.7341961471466489}]}},
#  {'text': '.',
#   'confidence': 0.60911226,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.125,
#      'y': 0.7723954877239548},
#     {'x': 0.2295, 'y': 0.7723954877239548},
#     {'x': 0.2295, 'y': 0.8500331785003318},
#     {'x': 0.125, 'y': 0.8500331785003318}]}},
#  {'text': 'VINCE',
#   'confidence': 0.7556486,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.458,
#      'y': 0.7777040477770405},
#     {'x': 0.5245, 'y': 0.7750497677504977},
#     {'x': 0.5255, 'y': 0.8128732581287326},
#     {'x': 0.4585, 'y': 0.8161911081619111}]}},
#  {'text': '2021/10/15',
#   'confidence': 0.99955404,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.5875,
#      'y': 0.7617783676177837},
#     {'x': 0.7355, 'y': 0.7558062375580624},
#     {'x': 0.7365, 'y': 0.8022561380225613},
#     {'x': 0.5885, 'y': 0.807564698075647}]}},
#  {'text': '.',
#   'confidence': 0.8023063,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.8195,
#      'y': 0.7976111479761114},
#     {'x': 0.8455, 'y': 0.7976111479761114},
#     {'x': 0.8455, 'y': 0.8135368281353683},
#     {'x': 0.8195, 'y': 0.8135368281353683}]}},
#  {'text': '.',
#   'confidence': 0.7507085,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.8645,
#      'y': 0.8002654280026543},
#     {'x': 0.8735, 'y': 0.8002654280026543},
#     {'x': 0.8735, 'y': 0.807564698075647},
#     {'x': 0.8645, 'y': 0.807564698075647}]}},
#  {'text': '.',
#   'confidence': 0.6995067,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.875,
#      'y': 0.79628400796284},
#     {'x': 0.898, 'y': 0.79628400796284},
#     {'x': 0.898, 'y': 0.809555408095554},
#     {'x': 0.875, 'y': 0.809555408095554}]}},
#  {'text': '.',
#   'confidence': 0.74205714,
#   'boundingPolygon': {'normalizedVertices': [{'x': 0.1645,
#      'y': 0.8546781685467817},
#     {'x': 0.2195, 'y': 0.8546781685467817},
#     {'x': 0.2195, 'y': 0.8838752488387525},
#     {'x': 0.1645, 'y': 0.8838752488387525}]}}]

# %%
def xyxy_to_xywh(x1, y1, x2, y2):
    return x1, y1, x2 - x1, y2 - y1

def xyxy_to_cxcywh(x1, y1, x2, y2):
    return (x1 + x2) / 2, (y1 + y2) / 2, x2 - x1, y2 - y1

# %%
fig, ax = plt.subplots()

ax.imshow(image)

for word in words:
    x, y, w, h = xyxy_to_xywh(word["boundingPolygon"]["normalizedVertices"][1]["x"], word["boundingPolygon"]["normalizedVertices"][1]["y"],
                                word["boundingPolygon"]["normalizedVertices"][3]["x"], word["boundingPolygon"]["normalizedVertices"][3]["y"])
    
    cx, cy, w, h = xyxy_to_cxcywh(word["boundingPolygon"]["normalizedVertices"][1]["x"], word["boundingPolygon"]["normalizedVertices"][1]["y"],
                                word["boundingPolygon"]["normalizedVertices"][3]["x"], word["boundingPolygon"]["normalizedVertices"][3]["y"])
    
    rect = patches.Rectangle((x * width, y * height), w * width, h * height, linewidth=1, edgecolor='blue', facecolor='white')

    ax.text(cx * width, cy * height, word["text"], horizontalalignment='center',
    verticalalignment='center', fontsize=6, color='black', fontfamily="Tahoma")
    # Add the patch to the Axes
    ax.add_patch(rect)

plt.savefig('output.png')
plt.show()
